# %%
import json 
import tensorflow as tf

# %%
path = "./output.jpg"

# %%
tf.expand_dims(tf.io.read_file(path), axis=0)
# Out:
# <tf.Tensor: id=27, shape=(1,), dtype=string, numpy=
# ...

# %%
tf.io.read_file(path)
# Out:
# <tf.Tensor: id=23, shape=(), dtype=string, numpy=b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00C\x00\x03\x02\x02\x02\x02\x02\x03\x02\x02\x02\x03\x03\x03\x03\x04\x06\x04\x04\x04\x04\x04\x08\x06\x06\x05\x06\t\x08\n\n\t\x08\t\t\n\x0c\x0f\x0c\n\x0b\x0e\x0b\t\t\r\x11\r\x0e\x0f\x10\x10\x11\x10\n\x0c\x12\x13\x12\x10\x13\x0f\x10\x10\x10\xff\xdb\x00C\x01\x03\x03\x03\x04\x03\x04\x08\x04\x04\x08\x10\x0b\t\x0b\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\x10\xff\xc0\x00\x11\x08\x01\x18\x01\x18\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1e\x00\x01\x00\x02\x03\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x08\t\x06\x07\n\x05\x03\x04\x01\x02\xff\xc4\x00N\x10\x00\x01\x03\x02\x04\x03\x03\x05\x0b\x07\x07\r\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\x07\x08\x11\t\x12!\x13\x141\x15AQa\x81\x19"8Wqw\x91\x92\
# ...

# %%
def preprocess_image(path):
    img_raw = tf.expand_dims(tf.io.read_file(path), axis=0)
    image = tf.image.decode_jpeg(img_raw, channels=3)
    image = tf.image.resize(image, [28, 28])
    image = (255 - image) / 255.0  # normalize to [0,1] range
    image = tf.reshape(image, (1, 28, 28, 1))
    return image

# %%
preprocess_image(path)
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-18-8c5161eb117a> in <module>
# ----> 1 preprocess_image(path)
#
# <ipython-input-17-76da926e1c84> in preprocess_image(path)
#       1 def preprocess_image(path):
#       2     img_raw = tf.expand_dims(tf.io.read_file(path), axis=0)
# ----> 3     image = tf.image.decode_jpeg(img_raw, channels=3)
#       4     image = tf.image.resize(image, [28, 28])
#       5     image = (255 - image) / 255.0  # normalize to [0,1] range
#
# ~/miniconda3/envs/cs_ftmle/lib/python3.7/site-packages/tensorflow_core/python/ops/gen_image_ops.py in decode_jpeg(contents, channels, ratio, fancy_upscaling, try_recover_truncated, acceptable_fraction, dct_method, name)
#    1176             try_recover_truncated=try_recover_truncated,
#    1177             acceptable_fraction=acceptable_fraction, dct_method=dct_method,
# ...

# %%
def preprocess_single_image(image_bytes, h=28, w=28):
    image = tf.image.decode_jpeg(image_bytes[0], channels=3)
    image = tf.image.resize(image, size=[h, w])
    image = (image - 127.5) / 127.5
    image = tf.expand_dims(image, axis=0)
    return image

# %%
input_data_json =
